# %% [markdown]
# ## Webscrapping NIVEL 2

# %% [markdown]
# ### 2.3.- Extracción en dos dimensiones horizontales en IGN con Scrapy

# %% [markdown]
# **OBJETIVO:**
#     - Extraer informacion sobre Articulos, Reviews y Videos en IGN
#     - Aprender a realizar extracciones de informacion de diferente tipo al mismo tiempo
#     - Aprender a realizar extracciones verticales y horizontales utilizando reglas
#     - Aprender a realizar extracciones con dos dimensiones de horizontalidad

# %%
import numpy as np
import pandas as pd
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import CrawlSpider,Rule
from scrapy.selector import Selector
from scrapy.loader.processors import MapCompose
from scrapy.linkextractors import LinkExtractor
from scrapy.loader import ItemLoader

# %%
class Articulo(Item):
    titulo = Field()
    contenido = Field()
    
class Review(Item):
    titulo = Field()
    calificacion = Field()

class Video(Item):
    titulo=Field()
    fecha_publicacion = Field()
    
class IGNCrawler(CrawlSpider):
    name = 'IGN'
    custom_settings = {
        'USER AGENT':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)Chrome/80.0.3987.149 Safari/537.36',
        'CLOSESPIDER_PAGECOUNT':30
    }
    
    allowed_domains = ['latam.ign.com']
    download_delay = 1
    start_urls = ['https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4']
    
    rules = (
        #Horizontalidad por tipo de información
         Rule(
            LinkExtractor(
                allow=r'type='
             ), follow=True
         ),
        # Horizontalidad por paginación
        Rule(
            LinkExtractor(
                allow = r'&page=\d+'
            ), follow = True
        
        ),
        # Horizontalidad por tipo de contenido
        #REVIEWS
        Rule(
            LinkExtractor(
                allow=r'/review/'
            ), follow=True,callback='parse_review'      
        ),
        #VIDEOS
        Rule(
            LinkExtractor(
                allow=r'/video/'
            ), follow=True,callback='parse_video'
        
        ),
        #ARTICULOS
        Rule(
            LinkExtractor(
                allow=r'/news/'            
            ), follow = True,callback='parse_news'  
        )
    )
    
    def parse_news(self,response):
        item = ItemLoader(Articulo(),response)
        item.add_xpath('titulo','//h1/text()')
        item.add_xpath('contenido','//div[@id="id_text"]//*/text()')
        
        yield item.load_item()
    
    def parse_review(self,response):
        item = ItemLoader(Review(),response)
        item.add_xpath('titulo','//h1/text()')
        item.add_xpath('calificacion','//span[@class="side-wrapper side-wrapper hexagon-content"]/text()')
        
        yield item.load_item()
        
    def parse_video(self,response):
        item = ItemLoader(Video(),response)
        item.add_xpath('titulo','//h1/text()')
        item.add_xpath('fecha_publicacion','//span[@class="publish-date"]/text()')
        
        yield item.load_item()

# %%
#from scrapy.spiders import Spider
#from scrapy.crawler import CrawlerProcess

#if __name__ == "__main__": # Código que se va a ejecutar al dar clic en RUN
#        process = CrawlerProcess()
#        process.crawl(IGNCrawler) # Nombre de la clase de mi Spider
#        process.start()

# %%
from Crawlerfunctions import *
crawlerapp(IGNCrawler)
# Out:
# 2020-12-30 17:41:31 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-30 17:41:31 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-12-30 17:41:31 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-30 17:41:31 [scrapy.crawler] INFO: Overridden settings:
# {'CLOSESPIDER_PAGECOUNT': 30}
# 2020-12-30 17:41:31 [scrapy.extensions.telnet] INFO: Telnet Password: 3d231f6cb002c19f
# 2020-12-30 17:41:31 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-30 17:41:31 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-30 17:41:31 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-30 17:41:31 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-30 17:41:31 [scrapy.core.engine] INFO: Spider opened
# 2020-12-30 17:41:31 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-30 17:41:31 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2020-12-30 17:41:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4> (referer: None)
# 2020-12-30 17:41:32 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://latam.ign.com/back-4-blood/74072/video/back-4-blood-trailer-cinematico#disqus_thread> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2020-12-30 17:41:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?model=keyword&q=ps4&kwtype=GAME&order_by=-date> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4&page=2> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?type=video&q=ps4&order_by=-date> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?type=review&q=ps4&order_by=-date> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/back-4-blood/74072/video/back-4-blood-trailer-cinematico> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/back-4-blood/74072/video/back-4-blood-trailer-cinematico>
# {'fecha_publicacion': ['10 de Diciembre de 2020'],
#  'titulo': ['Back 4 Blood - Trailer cinemático']}
# 2020-12-30 17:41:38 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.ign.com': <GET https://www.ign.com/sign-in?redirect=http%3A//latam.ign.com/back-4-blood/74072/video/back-4-blood-trailer-cinematico>
# 2020-12-30 17:41:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4&page=3> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/ign-latinoamerica/2308/news/bienvenidos-a-ign-latinoamerica> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/ign-latinoamerica/2308/news/bienvenidos-a-ign-latinoamerica>
# {'contenido': ['\u200b',
#                'IGN es el sitio número 1 de gaming y entretenimiento en el '
#                'mundo con una audiencia mundial de más de 50 millones y hoy, '
#                'estamos más que orgullosos de unirnos a esa increíble familia '
#                'con ¡IGN Latinoamérica!',
#                '¿Y qué puedes esperar de IGN Latinoamérica? Todo lo que '
#                'quieres, así de fácil. Estaremos trayendo a la región todo el '
#                'contenido internacional que tanto le gusta a la audiencia de '
#                'IGN: reviews, artículos y noticias, pero tropicalizados y en '
#                'español. También nos concentraremos en contenido local y lo '
#                'que le interesa a nuestro público regional.',
#                'Con el gaming en Latinoamérica creciendo en popularidad, como '
#                'si se hubiera comido un hongo, consideramos que es el momento '
#                'perfecto para lanzar IGN Latam y esperamos que todos lo '
#                'disfruten como nosotros al hacerlo.',
#                '\u200b',
#                'También es muy importante recordarte que si no quieres ver la '
#                'versión de IGN Latinoamérica (porque tal vez prefieras otra '
#                'edición) puedes cambiarla con sólo dar click en el nombre de '
#                'nuestra edición –ahí, arriba a la izquierda o en versión de '
#                'mobile hasta abajo– lo importante es que tengas la opción que '
#                'quieres.',
#                'En esta parte del proceso, es probable que encuentres pequeños '
#                'bugs en el sitio, pero queremos asegurarte que estamos '
#                'trabajando para resolver todos y cada uno de ellos. Si llegas '
#                'a encontrar alguno, cuéntanos para revisarlo lo más rápido '
#                'posible.',
#                'Y claro, no te olvides de seguirnos en nuestras redes sociales '
#                'en ',
#                'Facebook',
#                ', ',
#                '@IGNLatam',
#                ' y ',
#                'Google+',
#                ' para estar enterado todo el tiempo de todo lo que sucede en '
#                'el mundo del gaming y el entretenimiento.',
#                '¡Que comiencen los juegos!',
#                '\u200b',
#                'Mail de contacto:',
#                '\n',
#                'ign_latam@ign.com'],
#  'titulo': ['¡Bienvenidos a IGN Latinoamérica!']}
# 2020-12-30 17:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-1/73454/video/marvels-spider-man-comparacion-ps4-2018-vs-remasterizacion-para-ps5-2020> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-1/73454/video/marvels-spider-man-comparacion-ps4-2018-vs-remasterizacion-para-ps5-2020>
# {'fecha_publicacion': ['4 de Noviembre de 2020'],
#  'titulo': ["Marvel's Spider-Man: Comparación PS4 2018 vs. Remasterización "
#             'para PS5 2020']}
# 2020-12-30 17:41:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-1/73505/video/playstation-5-vs-playstation-4-pro-comparando-los-tiempos-de-carga> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-1/73505/video/playstation-5-vs-playstation-4-pro-comparando-los-tiempos-de-carga>
# {'fecha_publicacion': ['6 de Noviembre de 2020'],
#  'titulo': ['PlayStation 5 vs. PlayStation 4 Pro: comparando los tiempos de '
#             'carga']}
# 2020-12-30 17:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/spider-man-ps4/73578/video/los-primeros-22-minutos-de-spider-man-miles-morales-en-ps5-gameplay-en-4k> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/spider-man-ps4/73578/video/los-primeros-22-minutos-de-spider-man-miles-morales-en-ps5-gameplay-en-4k>
# {'fecha_publicacion': ['11 de Noviembre de 2020'],
#  'titulo': ['Los primeros 22 minutos de Spider-Man: Miles Morales en PS5 - '
#             'Gameplay en 4K']}
# 2020-12-30 17:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/forza-horizon-4/74075/video/forza-horizon-4-x-cyberpunk-2077-trailer-de-anuncio-de-dlc> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/forza-horizon-4/74075/video/forza-horizon-4-x-cyberpunk-2077-trailer-de-anuncio-de-dlc>
# {'fecha_publicacion': ['10 de Diciembre de 2020'],
#  'titulo': ['Forza Horizon 4 x Cyberpunk 2077 - Trailer de anuncio de DLC']}
# 2020-12-30 17:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-plus/73327/news/playstation-plus-estos-son-los-juegos-gratis-de-noviembre-de-2020-y-ya-se-incluye-uno-de-ps5> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-plus/73327/news/playstation-plus-estos-son-los-juegos-gratis-de-noviembre-de-2020-y-ya-se-incluye-uno-de-ps5>
# {'contenido': ['Sony Interactive Entertainment ha dado a conocer a través de ',
#                'PlayStation.Blog',
#                ' los juegos gratuitos de noviembre para los suscriptores de '
#                'PlayStation Plus, además de revelar más detalles sobre '
#                'PlayStation Plus Collection que llegará junto a PlayStation 5.',
#                'Para empezar tenemos que el juego de PlayStation 5 y los dos '
#                'títulos de ',
#                'PlayStation 4',
#                ' que podrán descargar los miembros de PlayStation Plus en '
#                'noviembre son:',
#                'Bugsnax (versión PS5)',
#                '\n',
#                'El primer juego de PS5 en unirse a PlayStation Plus es la '
#                'encantadora aventura en primera persona de Young Horses: '
#                'Bugsnax. Juega como un periodista investigador que se ha '
#                'propuesto investigar Snaktooth Island, hogar de legendarias '
#                'criaturas mitad insecto, mitad snack, Bugsnax. Descubre, caza '
#                'y captura todas las 100 criaturas mientras rastreas y reúnes '
#                'los habitantes de la isla.',
#                '\n\n',
#                'Bugsnax (versión PS5) estará disponible para los miembros de '
#                'PlayStation Plus a partir del jueves 12 de noviembre (para '
#                'propietarios de PS5) hasta el lunes 4 de enero de 2021.',
#                '\n',
#                'Middle-Earth: Shadow of War (PS4)',
#                '\n',
#                'Ubicado entre los eventos de El Hobbit y El Señor de los '
#                'Anillos, Middle-Earth: Shadow of War te invita una vez más al '
#                'icónico mundo de magos, orcos y elfos de JRR Tolkien. Ve '
#                'detrás de las líneas enemigas para forjar un ejército, '
#                'conquista fortalezas y domina Mordor desde adentro. '
#                'Experimenta cómo el Sistema Nemesis crea únicas historias '
#                'personales con cada enemigo y seguidor, y confronta todo el '
#                'poder del Señor Oscuro Sauron y sus Espectros del Anillo en '
#                'esta nueva y épica historia de la Tierra Media.',
#                '\n',
#                'Hollow Knight: Voidheart Edition (PS4)',
#                '\n',
#                'En el fascinante juego de plataformas de exploración en 2D de '
#                'Team Cherry, desciende hacia el extenso mundo subterráneo de '
#                'Hollownest para luchar contra criaturas contaminadas y hacerte '
#                'amigo de extraños bichos. Desbloquea nuevas habilidades y '
#                'adapta tus conjuntos de poderes a tu estilo de juego para '
#                'ayudarte a explorar retorcidas cavernas, antiguas ciudades y '
#                'mortales páramos. Descubre una antigua historia del reino, '
#                'enfrentando épicos jefes que desafiarán tus habilidades de '
#                'combate y plataformas mientras te esfuerzas por resolver los '
#                'misterios enterrados en su corazón.',
#                '\n',
#                'Estos dos juegos de PS4 estarán disponibles desde el martes 3 '
#                'de noviembre hasta el lunes 30 de noviembre.',
#                'PlayStation Plus Collection',
#                'Con el lanzamiento de PlayStation 5 llegará un nuevo beneficio '
#                'para la membresía de PlayStation Plus, se trata de PlayStation '
#                'Plus Collection que permitirá que los suscriptores tengan '
#                'acceso a una librería de juegos de PS4 que definieron la '
#                'generación.',
#                'La PlayStation Plus Collection se pondrá disponible a partir '
#                'del 12 de noviembre cuando PS5 se lance en Estados Unidos, '
#                'México, Japón y otros países, y estos son los juegos que '
#                'estarán disponibles:',
#                'De Sony Worldwide Studios:',
#                '\n\t',
#                'Bloodborne',
#                '\n\t',
#                'Days Gone',
#                '\n\t',
#                'Detroit: Become Human',
#                '\n\t',
#                'God of War',
#                '\n\t',
#                'Infamous Second Son',
#                '\n\t',
#                'Ratchet and Clank',
#                '\n\t',
#                'The Last Guardian',
#                '\n\t',
#                'The Last of Us Remastered',
#                '\n\t',
#                'Until Dawn',
#                '\n\t',
#                'Uncharted 4: A Thief’s End',
#                '\n',
#                'De estudios third-party:',
#                '\n\t',
#                'Batman: Arkham Knight',
#                '\n\t',
#                'Battlefield 1',
#                '\n\t',
#                'Call of Duty: Black Ops III – Zombies Chronicles Edition',
#                '\n\t',
#                'Crash Bandicoot N. Sane Trilogy',
#                '\n\t',
#                'Fallout 4',
#                '\n\t',
#                'Final Fantasy XV Royal Edition',
#                '\n\t',
#                'Monster Hunter: World',
#                '\n\t',
#                'Mortal Kombat X',
#                '\n\t',
#                'Persona 5',
#                '\n\t',
#                'Resident Evil 7 biohazard',
#                '\n',
#                'Por cierto, deben tener en cuenta que aún pueden descargar ',
#                'los juegos de octubre',
#                ' ya que Need for Speed: Payback y Vampyr estarán disponibles '
#                'como parte de los juegos de PS Plus hasta el 2 de noviembre.'],
#  'titulo': ['PlayStation Plus: estos son los juegos gratis de noviembre de '
#             '2020, y ya se incluye uno de PS5']}
# 2020-12-30 17:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-playstation-5/73480/news/playstation-5-no-seria-compatible-con-la-resolucion-nativa-de-1440p> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-playstation-5/73480/news/playstation-5-no-seria-compatible-con-la-resolucion-nativa-de-1440p>
# {'contenido': ['Parece que el PlayStation 5 no será compatible con la '
#                'resolución nativa de 1440p, ',
#                'de acuerdo a IGN Italia',
#                ', quienes aseguraron tener la confirmación oficial por parte '
#                'de Sony Europa este miércoles.',
#                'Esto es una mala noticia para los fans de PlayStation con '
#                'monitores de gaming de 1440p, ya que significa que el PS5 no '
#                'correrá algunos títulos con la resolución prevista y '
#                'probablemente tenga que reescalar desde 1080p para compensar. '
#                'IGN US ya se puso en contacto con Sony para comentarios al '
#                'respecto.',
#                ' ',
#                ' ',
#                'El PlayStation 5 puede generar una resolución máxima de 8K y '
#                '4K a 120fps a través de televisores compatibles con HDMI 2.1. '
#                'También correrá a resolución 1080p, pero la resolución '
#                'intermedia utilizada por muchos jugadores de PC, aparentemente '
#                'no será compatible con la nueva consola en el lanzamiento.',
#                'A principios de esta semana se reveló que Days Gone, el título '
#                'exclusivo de PS4, se ejecutará hasta 60fps en PlayStation 5 '
#                'con Dynamic 4K. El control Dualsense también contará, '
#                'aparentemente, con una placa afrontar extrapole que podría '
#                'intercambiarse con diseños personalizados.',
#                'Oficialmente, el PlayStation 5 llega a nuestra región el 12 de '
#                'noviembre.',
#                'En más sobre la esperada consola de Sony, dale un vistazo a: ',
#                'el DualSense funcionaría con el Nintendo Switch',
#                '.'],
#  'titulo': ['PlayStation 5 no sería compatible con la resolución nativa de '
#             '1440p']}
# 2020-12-30 17:41:48 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'it.ign.com': <GET https://it.ign.com/ps5/175513/news/ps5-brutte-notizie-per-i-pc-gamer-la-nuova-console-non-supportera-la-risoluzione-a-1440p>
# 2020-12-30 17:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-4-gaming-hardware/73509/news/playstation-5-con-su-proximo-lanzamiento-ps4-esta-bajando-de-precio-y-estas-son-las-mejores-ofertas> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-4-gaming-hardware/73509/news/playstation-5-con-su-proximo-lanzamiento-ps4-esta-bajando-de-precio-y-estas-son-las-mejores-ofertas>
# {'contenido': ['PlayStation 5 llegará al mercado la próxima semana, pero si '
#                'resulta que no compraron la PlayStation 4 y están considerando '
#                'hacerlo ahora, les podemos decir que es un buen momento para '
#                'hacerlo considerando que pueden conseguirla a un buen precio y '
#                'que cuenta con un enorme catálogo de juegos que fue acumulando '
#                'a lo largo de los años.',
#                'La PS4 ha estado bajando de precio y seguramente bajará más en '
#                'los próximos meses, pero por ejemplo en México actualmente es '
#                'posible conseguirla con importantes descuentos ya que está muy '
#                'cerca de comenzar "El Buen Fin" que es un período de ofertas '
#                'en múltiples establecimientos y tiendas online.',
#                'Como muestra de esto, en Walmart pueden conseguir el llamado '
#                'Mega Pack Bundle que incluye una consola PS4 de 1TB, 3 meses '
#                'de suscripción a PlayStation Plus, y los juegos God of War, '
#                'Uncharted The Nathan Drake Collection y Doom, por solo MXN '
#                '$7,996 en lugar de los MXN $9,299 que cuesta regularmente.',
#                'En Amazon México también está otro paquete Mega Pack de PS4 '
#                'que incluye una consola PS4 Slim de 1TB, un cupón de 3 meses '
#                'de PlayStation Plus y los juegos Horizon Zero Dawn, Days Gone, '
#                'GTA V y Fortnite por MXN $8,889 en lugar de su precio regular '
#                'de MXN $10,299.',
#                'En Amazon también hay otros paquetes interesantes, como el que '
#                'viene con la consola, los 3 meses de suscripción a PS Plus, y '
#                'GTA V, God of War y Death Stranding por MXN $7,671 en lugar de '
#                'MXN $9,699, y el bundle de PS4 Slim más FIFA 21 por MXN '
#                '$7,996.',
#                'Además, en sitios de descuentos están destacando que en '
#                "Elektra se puede conseguir la PS4 de 1TB más Marvel's "
#                'Spider-Man, Horizon Zero Dawn y Ratchet and Clank por MXN '
#                '$6,999 pagando con Paypal o por MXN $6,623 pagando con la '
#                'Tarjeta Azteca, y que en Costco está el Mega Pack con GTA V, '
#                'Days Gone, Horizon Zero Dawn y 3 meses de PS Plus por MXN '
#                '$5,999.',
#                'Si lo prefieren pueden optar por la nueva ',
#                'PlayStation 5',
#                ' que se lanzará este 12 de noviembre y habrá dos versiones '
#                'disponibles, una regular y una completamente digital.'],
#  'titulo': ['PlayStation 5: con su próximo lanzamiento, PS4 está bajando de '
#             'precio y estas son las mejores ofertas']}
# 2020-12-30 17:41:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/videojuegos/73622/news/xbox-one-ps4-ps5-switch-y-pc-estos-son-los-juegos-sin-costo-que-podras-conseguir-del-13-al-15-de-nov> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/videojuegos/73622/news/xbox-one-ps4-ps5-switch-y-pc-estos-son-los-juegos-sin-costo-que-podras-conseguir-del-13-al-15-de-nov>
# {'contenido': ['Como cada viernes les tenemos los juegos que pueden probar o '
#                'conseguir gratis durante este fin de semana, así que si les '
#                'pasa que no tienen nada nuevo que jugar o solo quieren probar '
#                'algo diferente, denle un vistazo al listado que incluye '
#                'títulos para PC, PlayStation 4, Xbox One y Nintendo Switch.',
#                'Por cierto, ya que para muchos es un fin de semana especial '
#                'debido a que están estrenando consola de siguiente generación, '
#                'tenemos que también hay un juego gratis para PlayStation 5.',
#                'A continuación pueden ver la lista de juegos, teniendo en '
#                'cuenta que algunos son solo pruebas temporales, otros son '
#                'regalos y algunos más son descargas gratuitas permanentes que '
#                'se otorgan por estar suscrito a algún servicio o como parte de '
#                'alguna promoción.',
#                'PC',
#                '\n\t',
#                'The Textorcist ',
#                '- Epic Games Store está regalando este juego. Podrán '
#                'descargarlo hasta el 19 de noviembre y se quedará en su '
#                'biblioteca de forma permanente.',
#                '\n\t',
#                'Grounded',
#                ' - Se puede jugar gratis en Steam hasta el 15 de noviembre. ',
#                '\n',
#                '\nXbox One',
#                '\n\t',
#                'Aragami: Shadow Edition',
#                ' - Como parte de ',
#                'los Games with Gold de noviembre',
#                '.',
#                '\n\t',
#                'Full Spectrum Warrior',
#                ' - Como parte de los Games with Gold de noviembre.',
#                '\n\t',
#                'Maid of Sker',
#                ' - Como parte de los Games with Gold de octubre, disponible '
#                'hasta el 15 de noviembre.',
#                '\n',
#                'PlayStation 5',
#                '\n\t',
#                'Bugsnax ',
#                '- La versión para PS5 está disponible como descarga gratuita '
#                'para los miembros de PS Plus propietarios de la nueva consola.',
#                '\n',
#                '\nPlayStation 4',
#                '\n\t',
#                'Middle-Earth: Shadow of War',
#                ' - Como parte de ',
#                'los juegos de PlayStation Plus de noviembre',
#                '.',
#                '\n\t',
#                'Hollow Knight: Voidheart Edition',
#                ' - Como parte de los juegos de PlayStation Plus de noviembre.',
#                '\n',
#                '\nNintendo Switch',
#                '\n\t',
#                'Jump Rope Challenge ',
#                '- Disponible como descarga gratuita (La descarga gratuita '
#                'sería solo hasta el 30 de septiembre, pero Nintendo decidió '
#                'extender el período)',
#                '\n\t',
#                'Super Mario Bros. 35',
#                ' - Disponible como ',
#                'descarga gratuita con Nintendo Switch Online',
#                '.',
#                '\n',
#                'Además de todos estos títulos también está la opción de varios '
#                'free-to-play disponibles para descargar en las diferentes '
#                'plataformas y por supuesto el catálogo de Xbox Game Pass con '
#                'muchas opciones para los suscriptores.'],
#  'titulo': ['Xbox One, PS4, PS5, Switch y PC: estos son los juegos sin costo '
#             'que podrás conseguir del 13 al 15 de noviembre']}
# 2020-12-30 17:41:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-1/73630/news/playstation-5-como-funciona-el-remote-play-en-playstation-4> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-1/73630/news/playstation-5-como-funciona-el-remote-play-en-playstation-4>
# {'contenido': ['Hace unos días Sony agregó la app de PS5 Remote Play a la '
#                'interfaz de PS4, lo que permite a los poseedores de ',
#                'PlayStation 5',
#                ' jugar en su anterior consola.',
#                'Y es que como sabrán, la función Remote Play utiliza '
#                'tecnología de streaming para correr juegos de PS5 en un '
#                'dispositivo diferente, como una PC, un smartphone o una PS4, '
#                'lo que puede ser útil en un hogar donde la televisión '
#                'principal está ocupada por otros miembros de la familia.',
#                'Dicho esto, les tenemos cómo utilizar el Remote Play de PS5 en '
#                'PS4:',
#                '\n\t',
#                'Obviamente necesitan una buena conexión a internet',
#                '\n\t',
#                '¡Tengan encendidas tanto su PS5 como su PS4 para facilitar los '
#                'siguientes pasos! Esto también se simplifica si ha iniciado '
#                'sesión en su PS5 y PS4 con la misma cuenta de PSN.',
#                '\n\t',
#                'En tu PS5, ve a Configuración> Sistema> Remote Play.',
#                '\n\t',
#                'Asegúrate de que "Enable Remote Play" (Permitir Remote Play) '
#                'está activado.',
#                '\n\t',
#                'En su PS4 seleccionen la aplicación PS5 Remote Play.',
#                '\n\t',
#                'Después de conectarse a Internet, la PS4 detectará la PS5 en '
#                'la que iniciaron sesión anteriormente.',
#                '\n\t',
#                'Conéctenlo. ¡Ahora estarán jugando a la PS5 en su PS4!',
#                '\n',
#                '\n\t',
#                'Nota: Otros usuarios de esa PS4 también podrán conectarse a su '
#                'PS5, siempre que estén todos en la misma red wifi.',
#                '\n\t',
#                'Para desconectarse, presionen el botón PlayStation y '
#                'seleccionen desconectar. Elijan poner su PS5 en modo de reposo '
#                'o déjenla encendida.',
#                '\n',
#                'Si los pasos anteriores no funcionan, es posible que deban '
#                'vincular manualmente el dispositivo. En cuyo caso, vayan a '
#                'Configuración de PS5> Sistema> Remote Play> Vincular '
#                'dispositivo. Aparecerá un código en la pantalla que puede '
#                'ayudarlos a conectarse si se le solicita que ingrese un '
#                'código.',
#                'PlayStation 5',
#                ' ya está disponible en México, Estados Unidos, Canadá, Nueva '
#                'Zelanda, Japón y Corea del Sur, y a partir del 19 de noviembre '
#                'llegará al resto del mundo.'],
#  'titulo': ['PlayStation 5: ¿cómo funciona el Remote Play en PlayStation 4?']}
# 2020-12-30 17:41:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/call-of-duty-black-ops-cold-war/73652/news/call-of-duty-black-ops-cold-war-usuarios-de-ps5-podrian-estar-jugando-la-version-de-ps4-por-error> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/call-of-duty-black-ops-cold-war/73652/news/call-of-duty-black-ops-cold-war-usuarios-de-ps5-podrian-estar-jugando-la-version-de-ps4-por-error>
# {'contenido': ['Para aquellos que pudieron asegurar una PlayStation 5 en su '
#                'lanzamiento y han estado jugando ',
#                'Call of Duty: Black Ops Cold War',
#                ', existe la posibilidad de que hayan estado jugando la versión '
#                'de PS4 por accidente.',
#                'De acuerdo al reporte de Eurogamer, este problema parece estar '
#                'afectando a ciertas personas que han comprado y descargado el '
#                'paquete Cross-Gen o la Ultimate Edition de Call of Duty: Black '
#                'Ops Cold War, que incluyen la versión para PS4 y PS5 del más '
#                'reciente Call of Duty.',
#                'Cuando compras cualquiera de estas versiones en PlayStation '
#                'Store, puedes elegir qué partes de ',
#                'Black Ops Cold War',
#                ' deseas descargar, es decir, Zombies, Multijugador, Campaña. '
#                'Sin embargo, si eliges descargar todo, descargarás tanto la '
#                'versión de PS4 como la de PS5 del juego, y parece que la '
#                'versión de PS4 está predeterminada para algunos que juegan en '
#                'PS5.',
#                'El soporte de Activision ha respondido a este problema y ha '
#                'revelado los pasos necesarios para asegurarse de que estén '
#                'jugando con la versión correcta:',
#                '\n\t',
#                'Resalta el mosaico del juego en el Dashboard.',
#                '\n\t',
#                'Desplácese hacia abajo y resalte "Reproducir"',
#                '\n\t',
#                'Seleccione los 3 puntos y abra el menú',
#                '\n\t',
#                'Seleccione “PS5 | Completo | Call of Duty: Black Ops Cold War”',
#                '\n\t',
#                '¡Lanza y disfruta!',
#                '\n',
#                'Call of Duty: Black Ops Cold War',
#                ' esta disponible en versiones para PlayStation 4, PlayStation '
#                '5, Xbox One, Xbox Series X|S y PC.',
#                ' '],
#  'titulo': ['Call of Duty: Black Ops Cold War - usuarios de PS5 podrían estar '
#             'jugando la versión de PS4 por error']}
# 2020-12-30 17:41:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/videojuegos/73728/news/xbox-one-ps4-ps5-switch-y-pc-estos-son-los-juegos-sin-costo-que-podras-conseguir-del-20-al-22-de-nov> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4)
# 2020-12-30 17:41:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/videojuegos/73728/news/xbox-one-ps4-ps5-switch-y-pc-estos-son-los-juegos-sin-costo-que-podras-conseguir-del-20-al-22-de-nov>
# {'contenido': ['Como de costumbre les tenemos los juegos que pueden probar o '
#                'conseguir gratis durante este fin de semana, así que si les '
#                'pasa que no tienen nada nuevo que jugar o solo quieren probar '
#                'algo diferente, denle un vistazo al listado que incluye '
#                'títulos para PC, PlayStation 4, PlayStation 5, Xbox One y '
#                'Nintendo Switch.',
#                'A continuación pueden ver la lista de juegos que en esta '
#                'ocasión está un poco más escasa en comparación a semanas '
#                'anteriores, teniendo en cuenta que algunos son solo pruebas '
#                'temporales, otros son regalos y algunos más son descargas '
#                'gratuitas permanentes que se otorgan por estar suscrito a '
#                'algún servicio o como parte de alguna promoción.',
#                'PC',
#                '\n\t',
#                'Elite Dangerous ',
#                '- Epic Games Store está regalando este juego. Podrán '
#                'descargarlo hasta el 26 de noviembre y se quedará en su '
#                'biblioteca de forma permanente.',
#                '\n\t',
#                'The World Next Door',
#                ' - Epic Games Store está regalando este juego. Podrán '
#                'descargarlo hasta el 26 de noviembre y se quedará en su '
#                'biblioteca de forma permanente.',
#                '\n',
#                '\nXbox One',
#                '\n\t',
#                'Aragami: Shadow Edition',
#                ' - Como parte de los ',
#                'Games with Gold de noviembre',
#                '.',
#                '\n\t',
#                'Swimsanity!',
#                ' - Como parte de los Games with Gold de noviembre.',
#                '\n\t',
#                'LEGO Indiana Jones',
#                ' - Como parte de los Games with Gold de noviembre.',
#                '\n',
#                '\nPlayStation 5',
#                '\n\t',
#                'Bugsnax',
#                ' - La versión para PS5 está disponible como descarga gratuita '
#                'para los miembros de PS Plus propietarios de la nueva consola.',
#                '\n',
#                '\nPlayStation 4',
#                '\n\t',
#                'Middle-Earth: Shadow of War ',
#                '- Como parte de los juegos de ',
#                'PlayStation Plus de noviembre',
#                '.',
#                '\n\t',
#                'Hollow Knight: Voidheart Edition',
#                ' - Como parte de los juegos de PlayStation Plus de noviembre.',
#                '\n',
#                '\nNintendo Switch',
#                '\n\t',
#                'Jump Rope Challenge',
#                ' - Disponible como descarga gratuita (La descarga gratuita '
#                'sería solo hasta el 30 de septiembre, pero Nintendo decidió '
#                'extender el período)',
#                '\n\t',
#                'Super Mario Bros. 35',
#                ' - Disponible como ',
#                'descarga gratuita con Nintendo Switch Online',
#                '.',
#                '\n',
#                'Además de todos estos títulos también está la opción de varios '
#                'free-to-play disponibles para descargar en las diferentes '
#                'plataformas y por supuesto el catálogo de Xbox Game Pass con '
#                'muchas opciones para los suscriptores.'],
#  'titulo': ['Xbox One, PS4, PS5, Switch y PC: estos son los juegos sin costo '
#             'que podrás conseguir del 20 al 22 de noviembre']}
# 2020-12-30 17:41:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-4-gaming-hardware/70873/news/playstation-4-cuanto-tardan-los-robots-de-sony-en-fabricar-la-consola-la-respuesta-te-sorprendera> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4&page=2)
# 2020-12-30 17:41:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-4-gaming-hardware/70873/news/playstation-4-cuanto-tardan-los-robots-de-sony-en-fabricar-la-consola-la-respuesta-te-sorprendera>
# {'contenido': ['El PlayStation 4 ha estado a la venta en el mercado durante '
#                'casi 7 años. Con decenas de millones de consolas vendidas '
#                'alrededor del mundo y múltiples revisiones y versiones '
#                'alternativas como el PS4 Pro y los rediseños "Slim", muchos no '
#                'considerarían que la consola continúe en producción.',
#                'De acuerdo a ',
#                'Nikkei Asian Review',
#                ', un sitio que se dedica a recontar la cultura y vida en '
#                'Japón, esto está lejos de ser cierto. De hecho parece ser que '
#                'Sony ha logrado reducir el esfuerzo necesario en la '
#                'fabricación de nuevas consolas a una ciencia exacta: Su planta '
#                'de manufactura cerca de Tokyo cuenta con una serie de robots '
#                'que, junto a cuatro humanos, pueden crear un PS4 completamente '
#                'funcional y listo para venderse en tan sólo ',
#                '30 segundos',
#                '.',
#                '"En las afueras de Kisarazu, un gran edificio blanco se '
#                'levanta sobre un paisaje suburbano", dice el reporte de Nikkei '
#                'Asian Review. "Una vez dentro, los visitantes son recibidos '
#                'por el chirrido de motores mientras docenas de robots '
#                'fluidamente crean consolas PlayStation 4". De acuerdo a los '
#                'testigos, una línea de 32 robots trabajan en conjunto para '
#                'ensamblar (es decir, posicionar las piezas, conectar todo el '
#                'cableado, y asegurarse de que todo está en donde debe ir) una '
#                'consola a alta velocidad.',
#                'Fuera de estos robots, sólo hay 4 trabajadores humanos en toda '
#                'la planta manufacturera: Dos se encargan de alimentar la línea '
#                'de ensamblaje con las placas madre sobre las que se soldan e '
#                'instalan todos los componentes de tu PlayStation 4, y dos al '
#                'final de la línea se encargan de empaquetar los productos '
#                'creados por las máquinas.',
#                'El método ha sido perfeccionado por Sony, incluso creando '
#                'tecnología tan avanzada que es capas de adherir cables, cintas '
#                'y otras partes flexibles a las consolas, algo que antes era '
#                'impensable y por lo que se requerían montones de trabajadores '
#                'dentro de una fábrica. Por supuesto, no está claro si se '
#                'utilizará el mismo método para la fabricación de los '
#                'PlayStation 5, ya que esto está altamente especializado para '
#                'la consola actual.',
#                '¿Que opinas acerca de este eficiente trabajo? ¿Alguna vez te '
#                'habías preguntado cómo se construyeron tus dispositivos '
#                'favoritos?'],
#  'titulo': ['PlayStation 4: ¿cuánto tardan los robots de Sony en fabricar la '
#             'consola? La respuesta te sorprenderá']}
# 2020-12-30 17:41:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-playstation-5/72541/video/god-of-war-ragnarok-teaser-trailer> (referer: https://latam.ign.com/se/?type=video&q=ps4&order_by=-date)
# 2020-12-30 17:41:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-playstation-5/72541/video/god-of-war-ragnarok-teaser-trailer>
# {'fecha_publicacion': ['16 de Septiembre de 2020'],
#  'titulo': ['God of War: Ragnarok - Teaser Tráiler']}
# 2020-12-30 17:41:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/mlb-the-show-20/69016/review/review-mlb-the-show-20> (referer: https://latam.ign.com/se/?type=review&q=ps4&order_by=-date)
# 2020-12-30 17:41:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/mlb-the-show-20/69016/review/review-mlb-the-show-20>
# {'calificacion': ['8.5', '9', '7', '8', '8'],
#  'titulo': ['MLB The Show 20 - Review']}
# 2020-12-30 17:42:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/super-meat-boy-forever/74094/video/super-meat-boy-forever-trailer> (referer: https://latam.ign.com/back-4-blood/74072/video/back-4-blood-trailer-cinematico)
# 2020-12-30 17:42:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/super-meat-boy-forever/74094/video/super-meat-boy-forever-trailer>
# {'fecha_publicacion': ['10 de Diciembre de 2020'],
#  'titulo': ['Super Meat Boy Forever - Trailer']}
# 2020-12-30 17:42:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/the-last-of-us-2-ps4/69331/news/the-last-of-us-2-este-es-el-espacio-que-ocupara-en-el-disco-duro-de-ps4> (referer: https://latam.ign.com/se/?model=article%2Cvideo&order_by=-date&q=ps4&page=3)
# 2020-12-30 17:42:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/the-last-of-us-2-ps4/69331/news/the-last-of-us-2-este-es-el-espacio-que-ocupara-en-el-disco-duro-de-ps4>
# {'contenido': ['Sony Interactive Entertainment ha dado a conocer que la '
#                'descarga digital de The Last of Us Parte 2 requerirá de al '
#                'menos 100 GB de espacio libre en el disco duro.',
#                'La página del juego en la tienda estadounidense incluye el '
#                'requisito de espacio en la parte inferior entre los detalles '
#                'de licencia y derechos de autor. Ya era de conocimiento común '
#                'que el lanzamiento físico de The Last of Us Part 2 se '
#                'distribuiría en dos discos Blu-ray, por lo que no es '
#                'sorprendente que la descarga digital sea de tamaño '
#                'considerable.',
#                ' ',
#                'Red Dead Redemption 2 recuperó la tendencia de los dos discos '
#                'cuando se lanzó en octubre de 2018, pero evitó que tuviera que '
#                'cambiar a la mitad al incluir un disco de datos y un disco de '
#                'reproducción. Así que independientemente del formato que se '
#                'elija, asegúrense de limpiar el almacenamiento de su PS4 antes '
#                'del día del lanzamiento.',
#                'Ha sido una semana difícil para The Last of Us 2 después de '
#                'que ',
#                'se filtraron detalles importantes de la trama',
#                ' del juego a principios de semana. ',
#                'Consulten nuestra guía',
#                ' para ayudarles a mantenerse alejados de los spoilers. En '
#                'medio de todo el caos, Sony ',
#                'fijó una fecha de lanzamiento actualizada para el juego',
#                ', y The Last of Us Parte 2 ahora se lanzará el 19 de junio. '
#                'Originalmente, el juego ',
#                'se había retrasado indefinidamente',
#                ' debido a problemas en la cadena de suministro relacionados '
#                'con la pandemia de COVID-19.',
#                ' ',
#                'Por cierto, cuando se atrasó indefinidamente el juego fue '
#                'retirado de PlayStation Store y se hicieron reembolsos, pero '
#                'desde hace un par de días ',
#                'nuevamente es posible reservarlo en la tienda oficia',
#                'l.',
#                ' '],
#  'titulo': ['The Last of Us 2: este es el espacio que ocupará en el disco duro '
#             'de PS4']}
# 2020-12-30 17:42:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/ign-latinoamerica/60121/news/euforia-nervios-y-diversion-se-viven-en-el-ign-tournament?utm_source=recirc> (referer: https://latam.ign.com/ign-latinoamerica/2308/news/bienvenidos-a-ign-latinoamerica)
# 2020-12-30 17:42:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/ign-latinoamerica/60121/news/euforia-nervios-y-diversion-se-viven-en-el-ign-tournament?utm_source=recirc>
# {'contenido': ['Gritos de emoción, nervios de acero, decepción por las '
#                'derrotas, euforia por los triunfos y sobre todo, mucha '
#                'diversión es lo que se vive minuto a minuto en el IGN '
#                'Tournament, donde más de 700 gamers buscan quedarse con la '
#                'corona definitiva en Apex Legends y sobre todo, con los 36,000 '
#                'MXN que habrá para el vencedor.',
#                'El primer torneo de IGN Latinoamérica comenzó desde las 3:30 '
#                'de la tarde en las cuatro diferentes sedes de Arena en la '
#                'Ciudad de México: Antara, Santa Fe, Artz Pedregal y Mundo E. '
#                'Los entusiastas jóvenes participantes comenzaron a llegar '
#                'antes de la primera cita -en equipos o sólos- con el ánimo por '
#                'las nubes y confiando en su talento.',
#                ' ',
#                ' ',
#                ' ',
#                'Al momento de registrarse, cada uno de los 700 jugadores '
#                'recibió un kit de bienvenida que estaba formado por una bolsa, '
#                'termo y camisa de IGN Tournament, más un pastelito Gansito y '
#                'unas galletas Sponch. Tras el registro, muchos de ellos '
#                'decidieron inmortalizar su participación en el torneo con '
#                'fotos, videos y hasta transmisiones en vivo con sus '
#                'seguidores.',
#                ' ',
#                ' ',
#                ' ',
#                'Entre los participantes en Artz Pedregal se encuentra el '
#                'equipo representante de Timber Esports, dedicados a los battle '
#                'royale y formado por tres jóvenes especialistas en Apex '
#                'Legends. Ellos salieron victoriosos en la primera ronda del '
#                'Torneo y van a la cabeza con 20 kills y 119 puntos.',
#                ' ',
#                ' ',
#                ' ',
#                'Algunos otros jugadores llegaron solos, pero con la esperanza '
#                'de encontrar un equipo para compartir la intensa jornada que '
#                'se vive en las distintas sedes de Arena. Si un jugador llega '
#                'solo, se agrupa con otros gamers sin equipo, y quien sabe, '
#                'quizá la química aparezca en alguna de estas asociaciones '
#                'improvisadas y sean capaces de sorprender a más de uno.',
#                'La mayoría de los participantes son varones, pero entre todos '
#                'los gamers de Artz se encuentra una mujer, Paulina Ramírez, de '
#                '29 años, originaria de la Ciudad de México e integrante del '
#                'equipo “Los Ositos”, que aunque tienen un nombre muy tierno, '
#                'están en el Torneo dispuestos a arrasar.',
#                '“Cada uno tiene sus funciones en el equipo y yo soy la persona '
#                'que los cubre de los que les están disparando de lejos. Las '
#                'mujeres no somos malas jugando, sólo necesitamos a alguien que '
#                'nos guíe. Yo no soy estratégica, así que necesito que me '
#                'guíen. Yo voy directo a los golpes”, comentó la joven.',
#                ' ',
#                ' ',
#                ' ',
#                'Los jugadores tuvieron la oportunidad de escoger jugar en PC o '
#                'en consolas, Xbox One y PlayStation 4, pero sin importar la '
#                'plataforma, los gritos de los participantes inundaron todos '
#                'los rincones de Arena Artz Pedregal, pues aunque usaban '
#                'headsets, el tono de su voz era alto por la adrenalina del '
#                'momento.',
#                '“Tengo alguien atrás”, “¡No lo vi”, y “¡Está allá!” son '
#                'algunas de las frases más repetidas durante el IGN Tournament, '
#                'mientras los diferentes equipos buscan coronarse campeones de '
#                'Apex Legends.',
#                ' ',
#                ' ',
# ...
#                'Treyarch recientemente revelaron que el juego requerirá de '
#                'hasta 250 GB de espacio libre para los que deseen correrlo en '
#                'Ultra RTX en PC, aunque esa especificación será menor si no '
#                'necesitan que corra con los ajustes más altos.',
#                ' '],
#  'titulo': ['Call of Duty: Black Ops Cold War se fusionará con Warzone en '
#             'diciembre']}
# 2020-12-30 17:42:15 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://latam.ign.com/videojuegos/73728/news/xbox-one-ps4-ps5-switch-y-pc-estos-son-los-juegos-sin-costo-que-podras-conseguir-del-20-al-22-de-nov> from <GET https://latam.ign.com/videojuegos/73728/news/www.instagram.com/ignlatam>
# 2020-12-30 17:42:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-4-gaming-hardware/73509/news/playstation-5-con-su-proximo-lanzamiento-ps4-esta-bajando-de-precio-y-estas-son-las-mejores-ofertas?utm_source=recirc> (referer: https://latam.ign.com/playstation-4-gaming-hardware/70873/news/playstation-4-cuanto-tardan-los-robots-de-sony-en-fabricar-la-consola-la-respuesta-te-sorprendera)
# 2020-12-30 17:42:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-4-gaming-hardware/73509/news/playstation-5-con-su-proximo-lanzamiento-ps4-esta-bajando-de-precio-y-estas-son-las-mejores-ofertas?utm_source=recirc>
# {'contenido': ['PlayStation 5 llegará al mercado la próxima semana, pero si '
#                'resulta que no compraron la PlayStation 4 y están considerando '
#                'hacerlo ahora, les podemos decir que es un buen momento para '
#                'hacerlo considerando que pueden conseguirla a un buen precio y '
#                'que cuenta con un enorme catálogo de juegos que fue acumulando '
#                'a lo largo de los años.',
#                'La PS4 ha estado bajando de precio y seguramente bajará más en '
#                'los próximos meses, pero por ejemplo en México actualmente es '
#                'posible conseguirla con importantes descuentos ya que está muy '
#                'cerca de comenzar "El Buen Fin" que es un período de ofertas '
#                'en múltiples establecimientos y tiendas online.',
#                'Como muestra de esto, en Walmart pueden conseguir el llamado '
#                'Mega Pack Bundle que incluye una consola PS4 de 1TB, 3 meses '
#                'de suscripción a PlayStation Plus, y los juegos God of War, '
#                'Uncharted The Nathan Drake Collection y Doom, por solo MXN '
#                '$7,996 en lugar de los MXN $9,299 que cuesta regularmente.',
#                'En Amazon México también está otro paquete Mega Pack de PS4 '
#                'que incluye una consola PS4 Slim de 1TB, un cupón de 3 meses '
#                'de PlayStation Plus y los juegos Horizon Zero Dawn, Days Gone, '
#                'GTA V y Fortnite por MXN $8,889 en lugar de su precio regular '
#                'de MXN $10,299.',
#                'En Amazon también hay otros paquetes interesantes, como el que '
#                'viene con la consola, los 3 meses de suscripción a PS Plus, y '
#                'GTA V, God of War y Death Stranding por MXN $7,671 en lugar de '
#                'MXN $9,699, y el bundle de PS4 Slim más FIFA 21 por MXN '
#                '$7,996.',
#                'Además, en sitios de descuentos están destacando que en '
#                "Elektra se puede conseguir la PS4 de 1TB más Marvel's "
#                'Spider-Man, Horizon Zero Dawn y Ratchet and Clank por MXN '
#                '$6,999 pagando con Paypal o por MXN $6,623 pagando con la '
#                'Tarjeta Azteca, y que en Costco está el Mega Pack con GTA V, '
#                'Days Gone, Horizon Zero Dawn y 3 meses de PS Plus por MXN '
#                '$5,999.',
#                'Si lo prefieren pueden optar por la nueva ',
#                'PlayStation 5',
#                ' que se lanzará este 12 de noviembre y habrá dos versiones '
#                'disponibles, una regular y una completamente digital.'],
#  'titulo': ['PlayStation 5: con su próximo lanzamiento, PS4 está bajando de '
#             'precio y estas son las mejores ofertas']}
# 2020-12-30 17:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-playstation-5/65703/video/godfall-trailer-de-presentacion> (referer: https://latam.ign.com/playstation-5-playstation-5/72541/video/god-of-war-ragnarok-teaser-trailer)
# 2020-12-30 17:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-playstation-5/65703/video/godfall-trailer-de-presentacion>
# {'fecha_publicacion': ['13 de Diciembre de 2019'],
#  'titulo': ['Godfall - Tráiler de presentación']}
# 2020-12-30 17:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/playstation-5-1/72696/news/playstation-5-sony-confirmo-que-si-puedes-usar-los-discos-de-ps4?utm_source=recirc> (referer: https://latam.ign.com/mlb-the-show-20/69016/review/review-mlb-the-show-20)
# 2020-12-30 17:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/playstation-5-1/72696/news/playstation-5-sony-confirmo-que-si-puedes-usar-los-discos-de-ps4?utm_source=recirc>
# {'contenido': ['Una cuenta oficial de PlayStation ha confirmado que el '
#                'PlayStation 5 regular que cuenta con un lector Blu-ray será '
#                'capaz de hacer uso de los discos de PlayStation 4, por lo que '
#                'su retrocompatibilidad no se limita a títulos digitales.',
#                'Reportado por ',
#                'siliconera',
#                ', el tweet en cuestión fue publicado por la cuenta Ask '
#                'PlayStation JP en respuesta a un usuario de Twitter que '
#                'aseguraba que "un disco de PS4 no funcionará incluso cuando '
#                'sea insertado a un PS5". Sin embargo, la realidad es que la '
#                'retrocompatibilidad de la consola funcionará con todos los '
#                'discos de PS4 que sean compatibles.',
#                '"Si el juego de PS4 es soportado por las operaciones de '
#                'compatibilidad de PS5, las versiones de disco y digital se '
#                'pueden jugar como están en el PS5" dice el tweet en japonés. '
#                '"Si vas a jugar el juego de PS4 con un disco, por favor elige '
#                'el modelo con el lector de discos. Nos disculpamos por la '
#                'insuficiencia en el contacto de apoyo relacionado a [la '
#                'retrocompatibilidad] del PS5, ya que hicimos el addendum de '
#                'arriba".',
#                '\n',
#                'PS5の互換動作に対応したPS4のゲームであれば、ディスク版でもデジタル版でもPS5でそのままプレイ可能です。PS4のゲームをディスクでプレイする場合は、ディスクドライブ搭載モデルをお選び下さい。以上PS5の互換性に関する窓口対応について不足がございましたので補足してお詫び申し上げます。 ',
#                'pic.twitter.com/Ha0JZGHtf4',
#                '\n— Ask PlayStation JP (@AskPS_JP) ',
#                'September 23, 2020',
#                'Previamente habíamos escuchado que un "99 porciento" de los '
#                'juegos de PS4 que Sony ha puesto a prueba en el PS5 son '
#                'completamente retrocompatibles, pero lamentablemente esto no '
#                'se exiende a los juegos de PS1, PS2, o PS3.'],
#  'titulo': ['PlayStation 5: Sony confirmó que sí puedes usar los discos de '
#             'PS4']}
# 2020-12-30 17:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/super-meat-boy-forever/2346/video/8-minutes-of-super-meat-boy-forever-pax-prime> (referer: https://latam.ign.com/super-meat-boy-forever/74094/video/super-meat-boy-forever-trailer)
# 2020-12-30 17:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/super-meat-boy-forever/2346/video/8-minutes-of-super-meat-boy-forever-pax-prime>
# {'fecha_publicacion': ['1 de Septiembre de 2014'],
#  'titulo': ['8 Minutes of Super Meat Boy Forever - PAX Prime']}
# 2020-12-30 17:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/the-last-of-us-2-ps4/69739/news/the-last-of-us-2-el-playstation-pro-tendra-una-edicion-especial?utm_source=recirc> (referer: https://latam.ign.com/the-last-of-us-2-ps4/69331/news/the-last-of-us-2-este-es-el-espacio-que-ocupara-en-el-disco-duro-de-ps4)
# 2020-12-30 17:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/the-last-of-us-2-ps4/69739/news/the-last-of-us-2-el-playstation-pro-tendra-una-edicion-especial?utm_source=recirc>
# {'contenido': ['Sony reveló la edición especial de PS4 Pro basada en The Last '
#                'of Us 2, junto con otros periféricos. También hay una cerveza '
#                'que viene en camino.',
#                'La colección, lanzada junto con el juego el 19 de junio, '
#                'representa el nuevo tatuaje de Ellie, incluirá una PS4 Pro con '
#                'control, un disco duro Seagate de 2TB y auriculares '
#                'inalámbricos. Puedes verlos todos en la galería a '
#                'continuación:',
#                'Un paquete de PS4 Pro incluirá el control, una copia del juego '
#                'y un código para canjear contenido digital. Se venderá a $ '
#                '399.99 USD. El controlador se venderá por separado por $ 64.99 '
#                'USD. El auricular, con un elegante acabado en negro y rojo, se '
#                'venderá por $ 99.99 USD, y el Seagate Game Drive (un poco '
#                'menos discreto) se venderá a $ 89.99 USD.',
#                'El director de arte de Naughty Dog, John Sweeney, explicó que '
#                'la elección del tema de la consola se basó en la reacción de '
#                'los fanáticos al diseño: "Cuando revelamos The Last of Us Part '
#                'II, no teníamos idea de cuán rápido los fanáticos adoptarían '
#                'el tatuaje de Ellie. En un día, comenzamos a ver versiones de '
#                'la vida real en las redes sociales y los fanáticos han estado '
#                'compartiendo fotos de sus nuevos tatuajes con nosotros semana '
#                'tras semana desde entonces.',
#                '"Cuando surgió la oportunidad de crear una PS4 Pro '
#                'personalizada para The Last of Us Part II, trabajé con nuestro '
#                'diseñador gráfico en ese momento, Angel García, y consideramos '
#                'algunas ideas diferentes, pero seguimos volviendo al tatuaje '
#                'de Ellie. En ese punto, se había convertido en un símbolo del '
#                'juego y para la comunidad, al igual que el logotipo de Firefly '
#                'en el primer juego. Era la elección clara, pero nos '
#                'preguntamos: ¿qué pasaría si pudiera grabarse? No se había '
#                'hecho antes , así que no estábamos seguros de que fuera '
#                'posible, pero gracias a los increíbles esfuerzos de los '
#                'equipos de PlayStation, encontramos la manera ".'],
#  'titulo': ['The Last of Us 2: el Playstation Pro tendrá una edición especial']}
# 2020-12-30 17:42:22 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://latam.ign.com/ign-latinoamerica/60121/news/euforia-nervios-y-diversion-se-viven-en-el-ign-tournament> from <GET https://latam.ign.com/ign-latinoamerica/60121/news/www.instagram.com/ignlatam>
# 2020-12-30 17:42:24 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://latam.ign.com/playstation-5-1/70288/video/trailer-de-gameplay-de-deathloop-ps5> from <GET https://latam.ign.com/playstation-5-1/70288/video/www.instagram.com/ignlatam>
# 2020-12-30 17:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://latam.ign.com/the-last-of-us-2-ps4/69739/news/the-last-of-us-2-el-playstation-pro-tendra-una-edicion-especial> (referer: https://latam.ign.com/the-last-of-us-2-ps4/69331/news/the-last-of-us-2-este-es-el-espacio-que-ocupara-en-el-disco-duro-de-ps4)
# 2020-12-30 17:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://latam.ign.com/the-last-of-us-2-ps4/69739/news/the-last-of-us-2-el-playstation-pro-tendra-una-edicion-especial>
# {'contenido': ['Sony reveló la edición especial de PS4 Pro basada en The Last '
#                'of Us 2, junto con otros periféricos. También hay una cerveza '
#                'que viene en camino.',
#                'La colección, lanzada junto con el juego el 19 de junio, '
#                'representa el nuevo tatuaje de Ellie, incluirá una PS4 Pro con '
#                'control, un disco duro Seagate de 2TB y auriculares '
#                'inalámbricos. Puedes verlos todos en la galería a '
#                'continuación:',
#                'Un paquete de PS4 Pro incluirá el control, una copia del juego '
#                'y un código para canjear contenido digital. Se venderá a $ '
#                '399.99 USD. El controlador se venderá por separado por $ 64.99 '
#                'USD. El auricular, con un elegante acabado en negro y rojo, se '
#                'venderá por $ 99.99 USD, y el Seagate Game Drive (un poco '
#                'menos discreto) se venderá a $ 89.99 USD.',
#                'El director de arte de Naughty Dog, John Sweeney, explicó que '
#                'la elección del tema de la consola se basó en la reacción de '
#                'los fanáticos al diseño: "Cuando revelamos The Last of Us Part '
#                'II, no teníamos idea de cuán rápido los fanáticos adoptarían '
#                'el tatuaje de Ellie. En un día, comenzamos a ver versiones de '
#                'la vida real en las redes sociales y los fanáticos han estado '
#                'compartiendo fotos de sus nuevos tatuajes con nosotros semana '
#                'tras semana desde entonces.',
#                '"Cuando surgió la oportunidad de crear una PS4 Pro '
#                'personalizada para The Last of Us Part II, trabajé con nuestro '
#                'diseñador gráfico en ese momento, Angel García, y consideramos '
#                'algunas ideas diferentes, pero seguimos volviendo al tatuaje '
#                'de Ellie. En ese punto, se había convertido en un símbolo del '
#                'juego y para la comunidad, al igual que el logotipo de Firefly '
#                'en el primer juego. Era la elección clara, pero nos '
#                'preguntamos: ¿qué pasaría si pudiera grabarse? No se había '
#                'hecho antes , así que no estábamos seguros de que fuera '
#                'posible, pero gracias a los increíbles esfuerzos de los '
#                'equipos de PlayStation, encontramos la manera ".'],
#  'titulo': ['The Last of Us 2: el Playstation Pro tendrá una edición especial']}
# 2020-12-30 17:42:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://latam.ign.com/spider-man-ps4/53180/video/review-marvels-spider-man> from <GET https://latam.ign.com/spider-man-ps4/53180/video/www.instagram.com/ignlatam>
# 2020-12-30 17:42:28 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://latam.ign.com/forza-horizon-4/50671/video/creando-el-mclaren-senna-en-forza-horizon-4-ign-first> from <GET https://latam.ign.com/forza-horizon-4/50671/video/www.instagram.com/ignlatam>
# 2020-12-30 17:42:28 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 19305,
#  'downloader/request_count': 46,
#  'downloader/request_method_count/GET': 46,
#  'downloader/response_bytes': 967393,
#  'downloader/response_count': 46,
#  'downloader/response_status_count/200': 40,
#  'downloader/response_status_count/301': 6,
#  'dupefilter/filtered': 492,
#  'elapsed_time_seconds': 56.55867,
#  'finish_reason': 'closespider_pagecount',
#  'finish_time': datetime.datetime(2020, 12, 30, 16, 42, 28, 277908),
#  'item_scraped_count': 34,
#  'log_count/DEBUG': 83,
#  'log_count/INFO': 10,
#  'offsite/domains': 2,
#  'offsite/filtered': 69,
#  'request_depth_max': 4,
#  'response_received_count': 40,
#  'scheduler/dequeued': 46,
#  'scheduler/dequeued/memory': 46,
#  'scheduler/enqueued': 244,
#  'scheduler/enqueued/memory': 244,
#  'start_time': datetime.datetime(2020, 12, 30, 16, 41, 31, 719238)}
# 2020-12-30 17:42:28 [scrapy.core.engine] INFO: Spider closed (closespider_pagecount)
