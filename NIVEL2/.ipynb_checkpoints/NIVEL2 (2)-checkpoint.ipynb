# %% [markdown]
# ## Webscrapping NIVEL 2 - Extracción Vertical + Horizontal

# %%
import numpy as np
import pandas as pd
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import CrawlSpider,Rule
from scrapy.selector import Selector
from scrapy.loader.processors import MapCompose
from scrapy.linkextractors import LinkExtractor
from scrapy.loader import ItemLoader

# %% [markdown]
# ### 2.2.- Extracción Vertical + Horizontal con Scrapy en MercadoLibre

# %%
class Articulo(Item):
    titulo = Field()
    precio = Field()
    descripcion = Field()
    
class MercadoLibreCrawler(CrawlSpider):
    name = 'mercadoLibre'

    custom_settings = {
      'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36',
      'CLOSESPIDER_PAGECOUNT': 20 # Numero maximo de paginas en las cuales voy a descargar items. Scrapy se cierra cuando alcanza este numero
    }

    # Utilizamos 2 dominios permitidos, ya que los articulos utilizan un dominio diferente
    allowed_domains = ['articulo.mercadolibre.com.ec', 'listado.mercadolibre.com.ec']

    start_urls = ['https://listado.mercadolibre.com.ec/animales-mascotas/perros/']

    download_delay = 1

    # Tupla de reglas
    rules = (
        Rule( # REGLA #1 => HORIZONTALIDAD POR PAGINACION
            LinkExtractor(
                allow=r'/_Desde_\d+' # Patron en donde se utiliza "\d+", expresion que puede tomar el valor de cualquier combinacion de numeros
            ), follow=True),
        Rule( # REGLA #2 => VERTICALIDAD AL DETALLE DE LOS PRODUCTOS
            LinkExtractor(
                allow=r'/MEC-' 
            ), follow=True, callback='parse_items'), # Al entrar al detalle de los productos, se llama al callback con la respuesta al requerimiento
    )
    
    def limpiarTexto(self,texto):
        nuevotexto = texto.replace('\n',' ').replace('\r',' ').replace('\t',' ').strip()
        return nuevotexto
    
    def parse_items(self,response):
        item = ItemLoader(Articulo(),response)
        item.add_xpath('titulo','//h1/text()',MapCompose(self.limpiarTexto))
        item.add_xpath('descripcion','//div[@class="ui-pdp-description"]/p/text()',MapCompose(self.limpiarTexto))
        item.add_xpath('precio','//span[@class="price-tag-fraction"]/text()')
        
        yield item.load_item()

# %%
from scrapy.spiders import Spider
from scrapy.crawler import CrawlerProcess

if __name__ == "__main__": # Código que se va a ejecutar al dar clic en RUN
        process = CrawlerProcess()
        process.crawl(MercadoLibreCrawler) # Nombre de la clase de mi Spider
        process.start()
# Out:
# 2020-12-25 17:31:18 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-25 17:31:18 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-12-25 17:31:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-25 17:31:18 [scrapy.crawler] INFO: Overridden settings:
# {'CLOSESPIDER_PAGECOUNT': 20,
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 '
#                'Safari/537.36'}
# 2020-12-25 17:31:18 [scrapy.extensions.telnet] INFO: Telnet Password: c666818f18cf4104
# 2020-12-25 17:31:18 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-25 17:31:18 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-25 17:31:18 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-25 17:31:18 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-25 17:31:18 [scrapy.core.engine] INFO: Spider opened
# 2020-12-25 17:31:18 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-25 17:31:18 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-12-25 17:31:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/> (referer: None)
# 2020-12-25 17:31:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428745585-cachorros-pastor-aleman-envios-a-nivel-nacional-_JM#position=1&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:20 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51#root-app> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2020-12-25 17:31:20 [py.warnings] WARNING: C:\Users\aleex\anaconda3\lib\site-packages\ipykernel_launcher.py:39: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#
# 2020-12-25 17:31:20 [py.warnings] WARNING: C:\Users\aleex\anaconda3\lib\site-packages\ipykernel_launcher.py:40: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#
# 2020-12-25 17:31:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428745585-cachorros-pastor-aleman-envios-a-nivel-nacional-_JM>
# {'descripcion': ['CACHORROS PASTOR ALEMÁN ENVIOS A NIVEL NACIONAL',
#                  'VENDO EXELENTES EJEMPLARES EN GENÉTICA PASTOR ALEMÁN MACHOS '
#                  'Y HEMBRAS DE DOS MESES Y MEDIO DE EDAD FOTOS A LA VISTA',
#                  '',
#                  'DISPONEMOS DE CACHORROS MACHOS Y HEMBRAS',
#                  'FOTOS A LA VISTA VACUNADO Y DESPARASITADO CON SU RESPECTIVO '
#                  'CARNET',
#                  'PADRES DE PEDIGREE SE ENTREGA CON LA COPIA DE PEDIGREE DE '
#                  'LOS PADRES'],
#  'precio': ['360'],
#  'titulo': ['Cachorros Pastor Alemán Envios A Nivel Nacional']}
# 2020-12-25 17:31:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_451> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428659097-cama-mascotas-perros-gatos-calidad-premiun-_JM#position=44&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428659097-cama-mascotas-perros-gatos-calidad-premiun-_JM>
# {'descripcion': ['Camas para mascotas desde gatos, hasta perros grandes, son '
#                  'super confortable y con diseños atractivos y sobrios.',
#                  'tenemos 3 tamaños:',
#                  '- Small: para gatos y perros miniatura (Largo 57 cm, Ancho '
#                  '42 cm, Grosor 13 cm)...$10,98',
#                  '- Medium: para perros pequeños y medianos (Largo 68 cm, '
#                  'Ancho 48 cm, Grosor 14 cm).... $21,98',
#                  '- Large: para perros grandes ( Largo 80 cm, Ancho 56 cm, '
#                  'Grosor 15 cm)...... $29,98'],
#  'precio': ['9'],
#  'titulo': ['Cama Mascotas Perros, Gatos, Calidad Premiun']}
# 2020-12-25 17:31:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428722081-mochila-bolso-con-capsula-transportar-perros-gatos-mascotas-_JM#position=43&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428722081-mochila-bolso-con-capsula-transportar-perros-gatos-mascotas-_JM>
# {'descripcion': ['Perfecto para visitas al Veterinario, paseos, viajes por '
#                  'carro/avión o recorrer lugares públicos.',
#                  'Las mochilas están aprobadas por la TSA (Administración en '
#                  'la Seguridad del Transporte USA) para que puedas llevar a tu '
#                  'mascota en cabina de avión sin ningún problema.',
#                  '• dos rejillas de respiración a los lados y una rejilla '
#                  'frontal, para que su mascotita pueda percibir la brisa y '
#                  'respire aire fresco',
#                  '• tiene dos ingresos para tu gatito o perrito, uno en la '
#                  'parte lateral, además el cierre principal que es muy amplio.',
#                  '• Cuenta con una colchoneta cómoda para que tu mascotita '
#                  'viaje relax, es removible y fácil de limpiar',
#                  '• Adentro de la mochila tiene un enganche para sujetar la '
#                  'correa de tu mascota',
#                  '• Cobertura transparente ( poli carbonato de calidad '
#                  'alimentaria) para que puedan ver el exterior. Contiene '
#                  'orificios para una mejor circulación del aire.',
#                  '• Viene con Cápsula transparente la cual se puede retirar y '
#                  'colocar una rejilla la cual también se incluye en la maleta.',
#                  '• bolsillo lateral para llevar el agua de tu mascotita'],
#  'precio': ['24'],
#  'titulo': ['Mochila Bolso Con Cápsula  Transportar Perros Gatos Mascotas']}
# 2020-12-25 17:31:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_401> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428364186-peine-electrico-eliminador-de-pulgas-y-garrapatas-mascotas-_JM#position=42&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428364186-peine-electrico-eliminador-de-pulgas-y-garrapatas-mascotas-_JM>
# {'descripcion': ['SOMOS DISTRIBUIDORA VASQUEZ, CONTAMOS CON LOCALES EN '
#                  'GUAYAQUIL, QUITO Y CUENCA',
#                  '-----------------------------------------------------------------------------------------',
#                  'GUAYAQUIL: URDESA CENTRAL AV. LAS AGUAS',
#                  '-----------------------------------------------------------------------------------------',
#                  'QUITO: NORTE SECTOR RUMIÑAHUI AV. REAL AUDIENCIA',
#                  '-----------------------------------------------------------------------------------------',
#                  'CUENCA: SECTOR MONAY AV. LOS ANDES',
#                  '--------------------------------------------------------------------------------------------------------------------------',
#                  'El articulo mata las pulgas rápidamente, es incoloro e '
#                  'inodoro para tus mascotas. No se necesitan pesticidas ni '
#                  'químicos.',
#                  'El peine cubre las pulgas muertas, y un botón de expulsión '
#                  'permite que tus manos se descarten.',
#                  'Ideal para actos y perros de todas las edades, seguro, el '
#                  'peine fácil de usar libera una carga eléctrica suave',
#                  'Mata pulgas en tus mascotas mientras preparas su piel',
#                  '',
#                  'Especificaciones:',
#                  'Tamaño del producto: 240X170X30mm/94,49X66,93/11,81"',
#                  'Material: de plástico',
#                  'Batería: 2 pilas AA (sin batería)',
#                  'Usos: Pet Anti pulgas',
#                  '',
#                  'REALIZAMOS ENVÍOS A TODO EL PAIS'],
#  'precio': ['5'],
#  'titulo': ['Peine Eléctrico Eliminador De Pulgas Y Garrapatas Mascotas']}
# 2020-12-25 17:31:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_351> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428309708-guante-quita-pelos-perros-gatos-mascotas-_JM#position=41&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428309708-guante-quita-pelos-perros-gatos-mascotas-_JM>
# {'descripcion': ['LOCALES EN QUITO SECTOR LA VILLAFLORA Y LA CAROLINA.',
#                  '',
#                  'Guante Quitapelos Para Mascotas:',
#                  'Con este guante quita pelos, su mascota sentirá un agradable '
#                  'masaje, mientras usted elimina todo su pelo muerto y deja su '
#                  'pelaje limpio y con brillo.',
#                  'Características principales:',
#                  '- Masajea.',
#                  '- Cepilla.',
#                  '- Recoge el pelo de animales.',
#                  '- Se adapta fácilmente a la mano.',
#                  '- Sirve para quitar pelos de la ropa, alfombra, asientos de '
#                  'carro, etc.',
#                  'EXCELENTE CALIDAD - ENTREGA INMEDIATA',
#                  'Formas de pago: Efectivo, depósito, transferencia bancaria, '
#                  'aceptamos todas las tarjetas de crédito.',
#                  'Costos de envío corren por cuenta del comprador.',
#                  'Horarios de atención son: lunes a Sábado: 9:00AM A 18:00PM, '
#                  'Domingos y Feriados 10:00 AM A 16:00 PM.'],
#  'precio': ['3'],
#  'titulo': ['Guante Quita Pelos Perros Gatos Mascotas']}
# 2020-12-25 17:31:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_301> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428239101-jaula-caja-kennel-transporte-perros-gatos-cachorros-animales-_JM#position=40&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428239101-jaula-caja-kennel-transporte-perros-gatos-cachorros-animales-_JM>
# {'descripcion': ['LOCALES EN QUITO SECTOR LA VILLA FLORA Y LA CAROLINA',
#                  'Kennel Jaula Caja Transporte Perros Gatos Cachorros Animales '
#                  'pequeños.',
#                  'Dimensiones : 49 cm largo x 29 alto x 29 ancho Precio 35 '
#                  'dólares',
#                  '',
#                  'Dimensiones : 60 cm largo x 35 alto x 35 ancho Precio 50 '
#                  'dólares',
#                  'Dimensiones : 70 cm largo x 45 alto x 45 ancho Precio 75 '
#                  'dólares',
#                  'Excelente calidad.',
#                  'Entrega inmediata.',
#                  '100 % Nuevo.',
#                  'Formas de pago: Efectivo, depósito, transferencia bancaria, '
#                  'aceptamos todas las tarjetas de crédito.',
#                  'Costos de envío corren por cuenta del comprador.',
#                  'Horarios de atención son: lunes a Sábado: 9:00AM A 18:00PM, '
#                  'Domingos y Feriados 10:00 AM A 16:00 PM.'],
#  'precio': ['35'],
#  'titulo': ['Jaula Caja Kennel Transporte Perros Gatos Cachorros Animales']}
# 2020-12-25 17:31:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_251> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_201> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428564452-dog-chow-adultos-medianos-y-grandes-227kg-_JM#position=39&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428564452-dog-chow-adultos-medianos-y-grandes-227kg-_JM>
# {'descripcion': ['PURINA® DOG CHOW® Adultos Razas Medianas y Grandes y Dog '
#                  'Chow Cachorros todos los tamaños',
#                  '',
#                  'Tu perro es único - ya creció y le fascina ser un miembro '
#                  'activo de tu familia. Es por eso que se merece un alimento '
#                  'que nutra todo lo que lo hace tan especial. PURINA® DOG '
#                  'CHOW® Adultos Razas Medianas y Grandes y Cachorros todas los '
#                  'tamaños está específicamente formulado con los nutrientes e '
#                  'ingredientes de calidad que lo ayudarán a tener salud y '
#                  'vitalidad por muchos más años.'],
#  'precio': ['60'],
#  'titulo': ['Dog Chow Adultos Medianos Y Grandes  22.7kg']}
# 2020-12-25 17:31:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428810156-ringo-cachorros-30kg-_JM#position=50&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428810156-ringo-cachorros-30kg-_JM>
# {'descripcion': ['Ringo CACHORROS es un alimento que satisface las necesidades '
#                  'nutricionales de las diferentes razas de perros cachorros, '
#                  'especialmente aquellos animales dedicados a actividades de '
#                  'campo. Además, ofrece la mejor relación costo - beneficio y '
#                  'aporta la energía que necesita tu perro para desarrollar sus '
#                  'actividades desde el inicio hasta el final del día.',
#                  '',
#                  '',
#                  'Rico en vitaminas',
#                  '',
#                  'Equilibrio de fibra y energía'],
#  'precio': ['42'],
#  'titulo': ['Ringo Cachorros 30kg']}
# 2020-12-25 17:31:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_151> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428189868-kit-de-rasuradora-para-mascotas-cortaunas-accesorios-_JM#position=49&type=item&tracking_id=d6e27108-f20d-4060-8de6-c3b725de6911> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428189868-kit-de-rasuradora-para-mascotas-cortaunas-accesorios-_JM>
# {'descripcion': ['SOMOS DISTRIBUIDORA VASQUEZ, CONTAMOS CON LOCALES EN '
#                  'GUAYAQUIL, QUITO Y CUENCA, PARA QUE REALICE SU COMPRA DE '
#                  'FORMA SEGURA Y CON GARANTIA',
#                  '------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  'GUAYAQUIL: AV. LAS AGUAS URDESA CENTRAL',
#                  'QUITO: SECTOR RUMIÑAHUI AV. REAL AUDIENCIA',
#                  'CUENCA: SECTOR TOTORACOCHA AV. LOS ANDES',
#                  '--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  'Descripción del producto:',
#                  'Super silencioso : motor de precisión, baja vibración y '
#                  'diseño ultra silencioso, libre de ruido de trabajo con sólo '
#                  'unos 50 db, para ayudar a la sensación de mascota a gusto, '
#                  'corte de pelo no miedo más. Motor potente (cuyo huso está '
#                  'hecho de cobre fino), no para sujetar y dañar el pelo del '
#                  'animal doméstico.',
#                  'Diseño sin cable: Diseño ligero e inalámbrico para un uso '
#                  'fácil. El kit de aseo para mascotas está equipado con un '
#                  'cargador. Carga de cinco horas, puede sostener usos de 70 '
#                  'minutos. Con la podadora inalámbrica, ya no puede ser '
#                  'molestado por el problema de reemplazar las baterías o '
#                  'cables aburridos.',
#                  '4 Combinaciones de guias: El peine de recorte ajustable es '
#                  'aplicable para cortar el pelo de diferentes longitudes; Y '
#                  'los peines desmontables de la guía hacen para cambios '
#                  'rápidos, fáciles del peine y la versatilidad creciente. Con '
#                  '4 peines guía de accesorio: adelgazamiento, (3mm / 6mm / 9mm '
#                  '/ 12mm), pieles que se ajustan a los contornos del cuello lo '
#                  'hacen seguro, fácil y cómodo.',
#                  'Lamina afilada: La lámina fija del acero inoxidable de la '
#                  'alta calidad y la lámina móvil proporcionan el '
#                  'funcionamiento excelente del corte. La hoja afilada bastante '
#                  'eventhough él después de un uso largo del tiempo y asegura '
#                  'la alta durabilidad. Cuchillas desmontables para facilitar '
#                  'el cambio y la limpieza: ajuste el ajuste del collar a 2,0 '
#                  'mm, luego sujete la cuchilla y empuje hacia abajo.',
#                  'Notificación: Si tu mascota tiene cabello largo y grueso, '
#                  'como los pastores alemanes, La Habana, Himalaya, Yorkie, '
#                  'necesitas usar tijeras (incluidas) cortar parte de ellos al '
#                  'principio, de lo contrario las podadoras se atascarán y no '
#                  'funcionarán correctamente.',
#                  '---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  'REALIZAMOS ENVIOS A TODO EL PAIS'],
#  'precio': ['19'],
#  'titulo': ['Kit De Rasuradora Para Mascotas + Cortauñas + Accesorios']}
# 2020-12-25 17:31:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_101> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2020-12-25 17:31:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428010112-kit-de-rasuradora-para-mascotas-cortaunas-accesorios-_JM#position=50&type=item&tracking_id=4babe944-73b6-46ea-95d5-964a8ee8e9c5> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51)
# 2020-12-25 17:31:31 [scrapy.core.engine] INFO: Closing spider (closespider_pagecount)
# 2020-12-25 17:31:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428010112-kit-de-rasuradora-para-mascotas-cortaunas-accesorios-_JM>
# {'descripcion': ['SOMOS DISTRIBUIDORA VASQUEZ, CONTAMOS CON LOCALES EN '
#                  'GUAYAQUIL, QUITO Y CUENCA, PARA QUE REALICE SU COMPRA DE '
#                  'FORMA SEGURA Y CON GARANTIA',
#                  '',
#                  '------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  'GUAYAQUIL: AV. LAS AGUAS URDESA CENTRAL',
#                  '',
#                  'QUITO: SECTOR RUMIÑAHUI AV. REAL AUDIENCIA',
#                  '',
#                  'CUENCA: SECTOR TOTORACOCHA AV. LOS ANDES',
#                  '',
#                  '--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  'Descripción del producto:',
#                  'Super silencioso : motor de precisión, baja vibración y '
#                  'diseño ultra silencioso, libre de ruido de trabajo con sólo '
#                  'unos 50 db, para ayudar a la sensación de mascota a gusto, '
#                  'corte de pelo no miedo más. Motor potente (cuyo huso está '
#                  'hecho de cobre fino), no para sujetar y dañar el pelo del '
#                  'animal doméstico.',
#                  'Diseño sin cable: Diseño ligero e inalámbrico para un uso '
#                  'fácil. El kit de aseo para mascotas está equipado con un '
#                  'cargador. Carga de cinco horas, puede sostener usos de 70 '
#                  'minutos. Con la podadora inalámbrica, ya no puede ser '
#                  'molestado por el problema de reemplazar las baterías o '
#                  'cables aburridos.',
#                  '4 Combinaciones de guias: El peine de recorte ajustable es '
#                  'aplicable para cortar el pelo de diferentes longitudes; Y '
#                  'los peines desmontables de la guía hacen para cambios '
#                  'rápidos, fáciles del peine y la versatilidad creciente. Con '
#                  '4 peines guía de accesorio: adelgazamiento, (3mm / 6mm / 9mm '
#                  '/ 12mm), pieles que se ajustan a los contornos del cuello lo '
#                  'hacen seguro, fácil y cómodo.',
#                  'Lamina afilada: La lámina fija del acero inoxidable de la '
#                  'alta calidad y la lámina móvil proporcionan el '
#                  'funcionamiento excelente del corte. La hoja afilada bastante '
#                  'eventhough él después de un uso largo del tiempo y asegura '
#                  'la alta durabilidad. Cuchillas desmontables para facilitar '
#                  'el cambio y la limpieza: ajuste el ajuste del collar a 2,0 '
#                  'mm, luego sujete la cuchilla y empuje hacia abajo.',
#                  'Notificación: Si tu mascota tiene cabello largo y grueso, '
#                  'como los pastores alemanes, La Habana, Himalaya, Yorkie, '
#                  'necesitas usar tijeras (incluidas) cortar parte de ellos al '
#                  'principio, de lo contrario las podadoras se atascarán y no '
#                  'funcionarán correctamente.',
#                  '',
#                  '---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------',
#                  '',
#                  'REALIZAMOS ENVIOS A TODO EL PAIS'],
#  'precio': ['20'],
#  'titulo': ['Kit De Rasuradora Para Mascotas + Cortauñas + Accesorios']}
# 2020-12-25 17:31:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428312878-227kg-dog-chow-cachorro-puppy-raza-mediana-grande-_JM#position=49&type=item&tracking_id=4babe944-73b6-46ea-95d5-964a8ee8e9c5> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51)
# 2020-12-25 17:31:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428312878-227kg-dog-chow-cachorro-puppy-raza-mediana-grande-_JM>
# {'descripcion': ['Purina® Dog Chow Cachorros Razas Medianas y Grandes',
#                  'Purina Dog Chow Cachorros Razas Medianas/Grandes, '
#                  'proporciona una mejor nutrición y nivel óptimo de energía '
#                  'para mantener una curva de crecimiento adecuada, promoviendo '
#                  'el sano desarrollo de las articulaciones y una óptima salud '
#                  'en cachorros de raza mediana o grande.',
#                  'El siste ma F.O.R. ayuda a formar:',
#                  '• Sano sistema inmunológico',
#                  '• Fuerte sistema digestivo',
#                  '• Fuertes huesos y músculos',
#                  'Atributo Detalle',
#                  'Garantía 1 Año',
#                  'Raza Medianas y grandes',
#                  'Observaciones La foto de este producto ha sido ambientada, '
#                  'por lo cual no incluye ningún adorno, ni accesorios, ni '
#                  'piezas adicionales ni ningún otro elemento que lo acompañan. '
#                  'El color presentado en la fotografía es una aproximación al '
#                  'color real.',
#                  'Contenido 22.7 kg',
#                  'Alto 64 cm',
#                  'Uso Alimento Seco Para Perros',
#                  'Ancho 44 cm',
#                  'Beneficios Alimento balanceado para cachorros de razas '
#                  'medianas y grandes que contribuye al desarrollo saludable de '
#                  'los perros más pequeños porque al igual que los bebés, los '
#                  'cachorros necesitan desarrollar su visión y su cerebro para '
#                  'estar más activos y preparados para aprender y jugar.',
#                  'Tipo alimento Alimento seco',
#                  'Tipo Comida seca cachorros',
#                  'Medidas 64x44x18 cm',
#                  'Características Alimento para cachorros de razas medianas y '
#                  'grandes, contiene DHA que ayuda al desarrollo del cerebro y '
#                  'la visión, calcio para un óptimo crecimiento huesos y '
#                  'dientes fuertes, proteínas a base de pollo para músculos '
#                  'fuertes, vitaminas y antioxidantes ayudan a fortalecer las '
#                  'defensas naturales e inulina para una sana digestión.',
#                  'Forma Croquetas de diversas formas',
#                  'Edad Cachorro',
#                  'Recomendaciones Alimento para cachorros entre 1 mes y 14 '
#                  'meses',
#                  'Largo 18 cm',
#                  'ANTES DE COMPRAR RECUERDE: -La compra es un compromiso '
#                  'serio, realice todas las preguntas necesarias antes de '
#                  'efectuarla. -Una vez realizada la compra se espera que la '
#                  'transacción se concrete dentro de los próximos 5 dias. '
#                  '-Usuarios con más puntos negativos que positivos abstenerse '
#                  'de comprar. -Usuarios nuevos de hacer la compra, deben '
#                  'comunicarse el mismo día. Caso contrario se calificará '
#                  'NEGATIVO. AGRADECEMOS SU COMPRENSION Nosotros estamos '
#                  'seguros de trabajar entre personas serias por tal razón será '
#                  'calificado negativo si no muestra la seriedad del caso. SI '
#                  'HA DECIDIDO COMPRAR HAGA UN SOLO CLICK COMPRAR y mis datos '
#                  'le llegaran a su correo tenga paciencia, si hace más de un '
#                  'click significa que va ha comprar más de uno. * * CUALQUIER '
#                  'INQUIETUD SERA RESPONDIDA CON MUCHO GUSTO'],
#  'precio': ['72'],
#  'titulo': ['22,7kg Dog Chow Cachorro Puppy Raza Mediana Grande']}
# 2020-12-25 17:31:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428438004-alimento-hipoalergenico-royal-canin-2-kg-envios-a-todo-pais-_JM#position=50&type=item&tracking_id=12d8cebc-54a6-41a9-a718-096b48224a9b> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_451)
# 2020-12-25 17:31:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428438004-alimento-hipoalergenico-royal-canin-2-kg-envios-a-todo-pais-_JM>
# {'descripcion': ['El vendedor no incluyó una descripción del producto'],
#  'precio': ['32'],
#  'titulo': ['Alimento Hipoalergenico Royal Canin 2 Kg Envios A Todo Pais']}
# 2020-12-25 17:31:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428217133-casas-para-mascotas-_JM#position=49&type=item&tracking_id=12d8cebc-54a6-41a9-a718-096b48224a9b> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_451)
# 2020-12-25 17:31:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428217133-casas-para-mascotas-_JM>
# {'descripcion': ['CASA CNEGRETE',
#                  'Pone a disposición',
#                  'CASAS PARA MASCOTAS',
#                  'PARA PERROS Y GATOS',
#                  'Diferentes tallas',
#                  'Muy resistentes',
#                  'Talla mini',
#                  'Talla #1',
#                  'Talla #2',
#                  'Talla #3',
#                  'Talla #4',
#                  'Envíos a domicilio tanto para el Norte, Sur y Valle de '
#                  'quito'],
#  'precio': ['16'],
#  'titulo': ['Casas Para Mascotas']}
# 2020-12-25 17:31:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428629521-dog-chow-cachorro-227kg-envio-gratis-helado-o-galletitas-_JM#position=50&type=item&tracking_id=fc6c8b30-8345-4c95-86b5-b351e0e9da94> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_401)
# 2020-12-25 17:31:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428629521-dog-chow-cachorro-227kg-envio-gratis-helado-o-galletitas-_JM>
# {'descripcion': ['Venta Dog chow cachorro Raza Mediana y Grande de 22.7kg '
#                  'entregas en Quito y los valles Gratis, Regalo adicional '
#                  'alimento húmedo de 400gr'],
#  'precio': ['69'],
#  'titulo': ['Dog Chow Cachorro 22.7kg  Envio Gratis+ Helado O Galletitas']}
# 2020-12-25 17:31:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428294592-kit-cortadora-de-pelo-para-mascotas-sonar-pet-clipper-perros-_JM#position=49&type=item&tracking_id=fc6c8b30-8345-4c95-86b5-b351e0e9da94> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_401)
# 2020-12-25 17:31:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428294592-kit-cortadora-de-pelo-para-mascotas-sonar-pet-clipper-perros-_JM>
# {'descripcion': ['DISTRIBUIDORA MONAR',
#                  'VENTAS AL POR MAYOR Y MENOR',
#                  '- Contamos con locales en Guayaquil y Milagro.',
#                  '- Realizamos entregas y envíos a nivel nacional con recargo.',
#                  '- Precios al por mayor a partir de 3 unidades iguales.',
#                  '- Descuentos del 10% por la compra de 3 o más productos '
#                  'variados.',
#                  '---------------------------------------------------------------------------',
#                  'Kit Cortadora De Pelo Para Mascota Sonar Pet Clipper',
#                  '- Kit completo Sonar corta pelo de Perro y Gatos, El motor '
#                  'de precisión con baja vibración y diseño ultra silencioso, '
#                  'Batería recargable de larga duración, Cuchilla de titanio se '
#                  'combina con la cuchilla móvil de cerámica para un corte '
#                  'eficiente y prolongado, Cuchilla calibrada con 5 niveles.',
#                  '- 4 Cepillo de Niveles',
#                  '- Peine de acero inoxidable',
#                  '- Cortauñas',
#                  '- Lima de uñas',
#                  '- Cepillo de limpieza',
#                  '- Accesorios de peine',
#                  '- Manual del usuario',
#                  '- Aceite Lubricante',
#                  '- Cargador'],
#  'precio': ['14'],
#  'titulo': ['Kit Cortadora De Pelo Para Mascotas Sonar Pet Clipper Perros']}
# 2020-12-25 17:31:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428589336-royal-canin-medium-junior-15kg-entrega-a-domicilio-quito-_JM#position=50&type=item&tracking_id=ee5b9e50-8146-4600-a00d-3b7f399c61f7> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_351)
# 2020-12-25 17:31:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428589336-royal-canin-medium-junior-15kg-entrega-a-domicilio-quito-_JM>
# {'descripcion': ['El mejor alimento para su mascota',
#                  'Gran promoción',
#                  'Se hace entrega a domicilio en Quito y sus valles',
#                  'Provincia envíos por coop de transporte'],
#  'precio': ['112'],
#  'titulo': ['Royal Canin Medium Junior 15kg Entrega A Domicilio Quito']}
# 2020-12-25 17:31:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428285821-cachorros-golden-retriever-_JM#position=49&type=item&tracking_id=ee5b9e50-8146-4600-a00d-3b7f399c61f7> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_351)
# 2020-12-25 17:31:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428285821-cachorros-golden-retriever-_JM>
# {'descripcion': ['Vendo lindos cachorros de dos meses de edad, son 100% puros,',
#                  'Disponemos de hembras y machos, tienen la primera vacuna '
#                  'correspondiente a parvo virus y la primera desparasitación, '
#                  'se le entrega con su respectivo carnet de vacunas.',
#                  '',
#                  'Los cachorritos ya comen croquetas, están vitaminados y se '
#                  'les colocó la pipeta anti pulgas por lo que son muy '
#                  'saludables, tienen un pelaje muy bonito, son súper '
#                  'juguetones y ya son independientes de sus padres por lo que '
#                  'están listos para formar parte de una familia.',
#                  'Se realizan entregas a domicilio en Quito, sin ningún cargo '
#                  'adicional.',
#                  'Ademas realizamos ENVÍOS A TODAS LAS PROVINCIAS:',
#                  '- TRANSPORTE TERRESTRE',
#                  '- VÍA AÉREA TAME',
#                  '- ENTREGAS EN PERSONA',
#                  '',
#                  'Formas de pago:',
#                  '- En caso de envío el pago se efectuará mediante depósito '
#                  'bancario, una vez efectuado el pago total del dinero '
#                  'acordado, se enviara el cachorrito.',
#                  '-Si usted desea que se le entregue personalmente, se '
#                  'realizará un adelanto por medio de depósito bancario y la '
#                  'diferencia me la cancela EN EFECTIVO el momento de la '
#                  'entrega.',
#                  '',
#                  'Si tiene dudas estaremos gustosos de responder a todas sus '
#                  'preguntas, o si desea puede realizar la compra sin ningún '
#                  'compromiso para que obtenga mis datos y así poder '
#                  'comunicarnos . SOMOS PERSONAS SERIAS, TENEMOS BUENA '
#                  'REPUTACIÓN EN LA PAGINA, NUESTROS CACHORROS SON PUROS, MUY '
#                  'SANOS, POR LO QUE USTED PUEDE DEPOSITAR TODA SU CONFIANZA EN '
#                  'NOSOTROS.'],
#  'precio': ['255'],
#  'titulo': ['Cachorros Golden Retriever']}
# 2020-12-25 17:31:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428481105-yorkshire-terrier-_JM#searchVariation=69529102092&position=50&type=item&tracking_id=445ead5f-7654-433e-81f3-cb19cdff9cc2> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_301)
# 2020-12-25 17:31:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428481105-yorkshire-terrier-_JM>
# {'descripcion': ['LINDOS CACHORROS DE RAZA PURA',
#                  'ESTÁN CON SU PRIMERA VACUNA Y DESPARASITADOS',
#                  'SE ENTREGA A NIVEL NACIONAL',
#                  'SON MUY HERMOSOS Y SE ADAPTAN A CUALQUIER TIPO DE HOGAR',
#                  'COMEN ALIMENTOS SÓLIDOS',
#                  'DISPONGO EN MACHO Y HEMBRA',
#                  'SON PERRITOS DE CASA'],
#  'precio': ['600'],
#  'titulo': ['Yorkshire Terrier']}
# 2020-12-25 17:31:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428095600-cachorros-labradores-_JM#position=49&type=item&tracking_id=445ead5f-7654-433e-81f3-cb19cdff9cc2> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_301)
# 2020-12-25 17:31:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428095600-cachorros-labradores-_JM>
# {'descripcion': ['Hermosos cachorritos hembra y machito vacunados y '
#                  'discapacitados entrega a domicilio de 2meses'],
#  'precio': ['280'],
#  'titulo': ['Cachorros Labradores']}
# 2020-12-25 17:31:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428260081-manguera-con-cepillo-masajeador-para-mascotas-anti-estres-_JM#position=50&type=item&tracking_id=c8d94369-7af0-4444-98ca-b77d484ad119> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_251)
# 2020-12-25 17:31:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428260081-manguera-con-cepillo-masajeador-para-mascotas-anti-estres-_JM>
# {'descripcion': ['Características:',
#                  '',
#                  'Este es un nuevo producto diseñado especialmente para el '
#                  'baño de masaje para mascotas.',
#                  '1. Poner guantes cuando se bañan mascotas, el agua se '
#                  'pulveriza automáticamente en el centro de la palma de su '
#                  'mano cuando se conecta al agua; no hay necesidad de un '
#                  'lavado de manguera adicional para liberar la otra mano.',
#                  '2. Hay más de 12mm levantado dientes en los guantes para '
#                  'bañar mascotas mientras también ayuda al cuerpo de la '
#                  'mascota al masaje; promover la circulación de la sangre del '
#                  'animal doméstico.',
#                  '3. Antes del baño, puede utilizar los dientes convexos en '
#                  'los guantes para peinar el pelo flotante en la mascota y '
#                  'enderezar el pelo.',
#                  '4. Los golpes de pulverización de agua con una altura de '
#                  'hasta 10mm pueden rociar directamente el agua en las raíces '
#                  'de el pelo de las mascotas. La limpieza más profunda, el '
#                  'lavado más limpio y la limpieza de las mascotas de pelo '
#                  'largo son muy apropiadas.',
#                  '',
#                  'Material: Protección Ambiental silicona + malla de nylon + '
#                  'PVC verde',
#                  'Adecuado para: perros, gatos, monos y cualquier otra '
#                  'mascota.',
#                  'Color principal: azul',
#                  'Incluye: 1 x Deshedding guante, 1 piezas tubo de agua, '
#                  'válvula de tubo de agua.',
#                  '',
#                  'Nuestro local de entrega en Quito está en el sector Norte '
#                  'Carcelén.',
#                  '',
#                  'Recuerde que GadiVentas le ofrece productos de calidad.',
#                  'Puede hacer su compra con tranquilidad y confianza.',
#                  '',
#                  'FORMAS DE PAGO: Efectivo, Depósito, Transferencia bancaria, '
#                  'aceptamos todas las tarjetas de crédito y débito.',
#                  '',
#                  'NUESTROS PRECIOS INCLUYEN IVA',
#                  '',
#                  'ENTREGA INMEDIATA: En nuestro local o Envíos a nivel '
#                  'nacional, por medio de Servientrega, Tramaco Express o la '
#                  'empresa de transporte de su preferencia, los gastos de envió '
#                  'lo asume el cliente.',
#                  '',
#                  'SOMOS GADIVENTAS.',
#                  '',
#                  'TENGA USTED UN FELIZ DÍA.'],
#  'precio': ['9'],
#  'titulo': ['Manguera Con Cepillo Masajeador Para Mascotas Anti Estres']}
# 2020-12-25 17:31:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428363859-cortadora-para-mascotas-wahl-maquina-para-perro-_JM#position=49&type=item&tracking_id=c8d94369-7af0-4444-98ca-b77d484ad119> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_251)
# 2020-12-25 17:31:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428363859-cortadora-para-mascotas-wahl-maquina-para-perro-_JM>
# {'descripcion': ['-Cuchillas afiladas de precisión de acero de alto carbono.',
#                  '-Poderoso motor patentado de V5000.',
#                  '-Cabezal de corte de precisión, de acero templado.',
#                  '-Silenciosa, ideal para trabajar con animales sensibles al '
#                  'ruido.',
#                  '-Recomendada para la cara, las patas y las terminaciones en '
#                  'animales de pelo corto.',
#                  'INCLUYE:',
#                  '-4 peines regulables: 3mm, 6mm, 10mm, 13 mm',
#                  '-Peine',
#                  '-Tijera',
#                  '-Aceite lubricante',
#                  '-Cepillo de limpieza',
#                  '-Protector de cuchillas',
#                  '-Instrucciones de uso super detalladas.',
#                  '-Estuche.',
#                  '*Antes de dar CLIP EN COMPRAR por favor confirme el STOCK*',
#                  '*****Envió gratis a partir de 4 Unidades dentro de Quito '
#                  '******'],
#  'precio': ['69'],
#  'titulo': ['Cortadora Para Mascotas Wahl Maquina Para Perro']}
# 2020-12-25 17:31:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428296036-propac-ultimates-cordero-arroz-12kg-antialergia-_JM#position=50&type=item&tracking_id=49ea2eaf-c9d8-4945-ad0f-76f12e80a844> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_201)
# 2020-12-25 17:31:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428296036-propac-ultimates-cordero-arroz-12kg-antialergia-_JM>
# {'descripcion': ['Informes y ventas solo WhatsApp haga la compra y tome '
#                  'contacto al WhatsApp'],
#  'precio': ['73'],
#  'titulo': ['Propac Ultimates Cordero Arroz  12kg Antialergia']}
# 2020-12-25 17:31:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428357202-doggimel-leche-cachorros-perros-y-gatos-100-gr-_JM#position=49&type=item&tracking_id=49ea2eaf-c9d8-4945-ad0f-76f12e80a844> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_201)
# 2020-12-25 17:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428357202-doggimel-leche-cachorros-perros-y-gatos-100-gr-_JM>
# {'descripcion': ['El vendedor no incluyó una descripción del producto'],
#  'precio': ['5'],
#  'titulo': ['Doggimel Leche Cachorros Perros Y Gatos 100 Gr']}
# 2020-12-25 17:31:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428448986-lindos-rottweiler-aleman-envios-y-entregas-_JM#position=50&type=item&tracking_id=62cb590a-d08c-461d-93cc-32b953f13bd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_151)
# 2020-12-25 17:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428448986-lindos-rottweiler-aleman-envios-y-entregas-_JM>
# {'descripcion': ['Rottweiler alemán disponible'],
#  'precio': ['350'],
#  'titulo': ['Lindos  Rottweiler Alemán Envíos Y Entregas']}
# 2020-12-25 17:31:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-428035674-husky-siberianos-_JM#position=49&type=item&tracking_id=62cb590a-d08c-461d-93cc-32b953f13bd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_151)
# 2020-12-25 17:31:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-428035674-husky-siberianos-_JM>
# {'descripcion': ['Vendo lindos cachorros husky siberianos de dos meses de '
#                  'edad, son 100% puros,',
#                  'Disponemos de hembras y machos, tienen la primera vacuna '
#                  'correspondiente a parvo virus y la primera desparasitación, '
#                  'se le entrega con su respectivo carnet de vacunas.',
#                  'Los cachorritos ya comen croquetas, están vitaminados y se '
#                  'les colocó la pipeta anti pulgas por lo que son muy '
#                  'saludables, tienen un pelaje muy bonito, son súper '
#                  'juguetones y ya son independientes de sus padres por lo que '
#                  'están listos para formar parte de una familia.',
#                  'Se realizan entregas a domicilio en Quito, sin ningún cargo '
#                  'adicional.',
#                  'Ademas realizamos entregas en personas en todo el país con '
#                  'un valor adicional dependiente de que tan lejos sea Los '
#                  'perritos husky siberianos son cariñosos ideales para niños '
#                  'muy juguetones alegres obedientes y muy inteligentes, es una '
#                  'raza grande para espacios grandes, casas, fincas, haciendas, '
#                  'todos los entregamos con el certificado de vacunas otorgado '
#                  'por el medico veterinario lo que le garantiza que son puros '
#                  'y sanos, si desea más información pueden comunicarse conmigo '
#                  'antes de hacer la compra estaré gustoso de responder sus '
#                  'inquietudes lo más rápido posible..'],
#  'precio': ['250'],
#  'titulo': ['Husky Siberianos']}
# 2020-12-25 17:31:50 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 20158,
#  'downloader/request_count': 35,
#  'downloader/request_method_count/GET': 35,
#  'downloader/response_bytes': 1543575,
#  'downloader/response_count': 35,
#  'downloader/response_status_count/200': 35,
#  'dupefilter/filtered': 133,
#  'elapsed_time_seconds': 32.595884,
#  'finish_reason': 'closespider_pagecount',
#  'finish_time': datetime.datetime(2020, 12, 25, 16, 31, 50, 933074),
#  'item_scraped_count': 25,
#  'log_count/DEBUG': 61,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 2,
#  'request_depth_max': 3,
#  'response_received_count': 35,
#  'scheduler/dequeued': 35,
#  'scheduler/dequeued/memory': 35,
#  'scheduler/enqueued': 551,
#  'scheduler/enqueued/memory': 551,
#  'start_time': datetime.datetime(2020, 12, 25, 16, 31, 18, 337190)}
# 2020-12-25 17:31:50 [scrapy.core.engine] INFO: Spider closed (closespider_pagecount)
